# %% [markdown]
# ## Part 1: Postal Codes

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup

# %% [markdown]
# We scrape the postal codes, boroughs, and neighborhoods using read_html to get the data from the Wikipedia page. We drop all rows where the boroughs have "Not assigned." Since no neighborhoods with an assigned boroughs are called "Not assigned," this is sufficient.

# %%
postal_codes = pd.read_html("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M")[0]
postal_codes.drop(postal_codes.index[postal_codes["Borough"] == "Not assigned"], inplace = True)
postal_codes.sort_values(by = ['Postal Code']).reset_index(drop=True)
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...

# %%
postal_codes.shape
# Out:
# (103, 3)

# %% [markdown]
# ## Part 2: Location of Postal Codes

# %% [markdown]
# Using the csv file, the geolocation data is merged with the postal code data where postal codes are the same.

# %%
lat_lng = pd.read_csv('Geospatial_Coordinates.csv')
geo_postal_codes = postal_codes.merge(lat_lng).sort_values(by = ['Postal Code']).reset_index(drop=True)
geo_postal_codes
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 16          M1X       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 21          M2M        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# ...

# %% [markdown]
# ## Part 3: Clustering Postal Codes

# %% [markdown]
# We will be clustering neighborhoods in Toronto in the same manner as done in the lab (i.e. using Foursquare to get venues and then cluster). We first need our client_id, client_secret, and version to access Foursquare:

# %%
CLIENT_ID = '0ZV3RKMX50FORVFJA44SPLYWYFYXILQ1MAIHIOWOL250GDPZ' # your Foursquare ID
CLIENT_SECRET = '3G234BSZCVM2ND5I152PPPDEQ50EWPPSKMR0YTCQZMYU2AXV' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# For each neighborhood, we get up to 100 venues that are within 500 of the geolocation.

# %%
LIMIT = 100
import requests

def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
toronto_venues = getNearbyVenues(names=geo_postal_codes['Neighborhood'],
                                latitudes = geo_postal_codes['Latitude'],
                                longitudes = geo_postal_codes['Longitude']
                                )
# Out:
# Malvern, Rouge
# Rouge Hill, Port Union, Highland Creek
# Guildwood, Morningside, West Hill
# Woburn
# Cedarbrae
# Scarborough Village
# Kennedy Park, Ionview, East Birchmount Park
# Golden Mile, Clairlea, Oakridge
# Cliffside, Cliffcrest, Scarborough Village West
# Birch Cliff, Cliffside West
# Dorset Park, Wexford Heights, Scarborough Town Centre
# Wexford, Maryvale
# Agincourt
# Clarks Corners, Tam O'Shanter, Sullivan
# Milliken, Agincourt North, Steeles East, L'Amoreaux East
# Steeles West, L'Amoreaux West
# Upper Rouge
# Hillcrest Village
# Fairview, Henry Farm, Oriole
# Bayview Village
# York Mills, Silver Hills
# Willowdale, Newtonbrook
# Willowdale, Willowdale East
# York Mills West
# Willowdale, Willowdale West
# Parkwoods
# Don Mills
# Don Mills
# Bathurst Manor, Wilson Heights, Downsview North
# Northwood Park, York University
# Downsview
# Downsview
# Downsview
# Downsview
# Victoria Village
# Parkview Hill, Woodbine Gardens
# Woodbine Heights
# The Beaches
# Leaside
# ...

# %% [markdown]
# We group all the neighborhoods and get the 10 most common venues for each neighborhood:

# %%
# one hot encoding
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")


# add neighborhood column back to dataframe
toronto_onehot['Neighborhood'] = toronto_venues['Neighborhood'] 


# move neighborhood column to the first column
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighborhood').mean().reset_index()

def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]


num_top_venues = 10

indicators = ['st', 'nd', 'rd']

# create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

# create a new dataframe
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = toronto_grouped['Neighborhood']

for ind in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(toronto_grouped.iloc[ind, :], num_top_venues)

# %% [markdown]
# We cluster neighborhoods into 5 clusters using k-means clustering:

# %%
from sklearn.cluster import KMeans

# set number of clusters
kclusters = 5

toronto_grouped_clustering = toronto_grouped.drop('Neighborhood', 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)

# add clustering labels
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
toronto_merged = geo_postal_codes

# merge toronto_grouped with toronto_data to add latitude/longitude for each neighborhood
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood',how = "right")
toronto_merged
# Out:
#     Postal Code           Borough  \
# 0           M1B       Scarborough
# 1           M1C       Scarborough
# 2           M1E       Scarborough
# 3           M1G       Scarborough
# 4           M1H       Scarborough
# 5           M1J       Scarborough
# 6           M1K       Scarborough
# 7           M1L       Scarborough
# 8           M1M       Scarborough
# 9           M1N       Scarborough
# 10          M1P       Scarborough
# 11          M1R       Scarborough
# 12          M1S       Scarborough
# 13          M1T       Scarborough
# 14          M1V       Scarborough
# 15          M1W       Scarborough
# 17          M2H        North York
# 18          M2J        North York
# 19          M2K        North York
# 20          M2L        North York
# 22          M2N        North York
# 23          M2P        North York
# 24          M2R        North York
# 25          M3A        North York
# 26          M3B        North York
# 27          M3C        North York
# ...

# %% [markdown]
# Finally, we can map the clusters:

# %%
#!conda install -c conda-forge folium=0.5.0 --yes 
import folium # map rendering library

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors

# create map
latitude = 43.651070
longitude = -79.347015
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=10)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighborhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# The first cluster seems to indicate areas with mainly relaxing and convenience shopping venues:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 0, toronto_merged.columns[[1]+[2] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#             Borough Neighborhood  Cluster Labels 1st Most Common Venue  \
# 63  Central Toronto     Roselawn               0                Garden
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 63         Women's Store            Donut Shop    Dim Sum Restaurant
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 63                 Diner        Discount Store   Distribution Center
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 63               Dog Run      Doner Restaurant              Drugstore

# %% [markdown]
# The second cluster seems to indicate areas where there are mainly leisure venues, like parks, trails, or playgrounds:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 1, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#              Borough  Cluster Labels 1st Most Common Venue  \
# 14       Scarborough               1                  Park
# 20        North York               1             Cafeteria
# 44   Central Toronto               1                  Park
# 50  Downtown Toronto               1                  Park
# 64   Central Toronto               1                 Trail
# 79        North York               1                 Trail
# 90         Etobicoke               1                 River
#
#    2nd Most Common Venue 3rd Most Common Venue       4th Most Common Venue  \
# 14            Playground         Women's Store                  Donut Shop
# 20                  Park            Donut Shop          Dim Sum Restaurant
# 44              Bus Line           Swim School               Women's Store
# 50            Playground                 Trail               Women's Store
# 64                  Park      Sushi Restaurant               Jewelry Store
# ...

# %% [markdown]
# The third cluster seems to indicate areas with mainly home and health venues:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 2, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#       Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 94  Etobicoke               2          Home Service         Women's Store
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 94             Drugstore                 Diner        Discount Store
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 94   Distribution Center               Dog Run      Doner Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 94            Donut Shop    Dumpling Restaurant

# %% [markdown]
# The fourth cluster seems to indicate areas with mainly dining or "essentials" shopping venues:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 3, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#               Borough  Cluster Labels          1st Most Common Venue  \
# 0         Scarborough               3           Fast Food Restaurant
# 1         Scarborough               3                  Moving Target
# 2         Scarborough               3                   Intersection
# 3         Scarborough               3                    Coffee Shop
# 4         Scarborough               3               Hakka Restaurant
# 5         Scarborough               3                  Women's Store
# 6         Scarborough               3               Department Store
# 7         Scarborough               3                       Bus Line
# 8         Scarborough               3                          Motel
# 9         Scarborough               3                           Café
# 10        Scarborough               3              Indian Restaurant
# 11        Scarborough               3                 Breakfast Spot
# 12        Scarborough               3             Chinese Restaurant
# ...

# %% [markdown]
# The fifth cluster seems to indicate areas with mainly relxation and hobby venues:

# %%
toronto_merged.loc[toronto_merged['Cluster Labels'] == 4, toronto_merged.columns[[1] + list(range(5, toronto_merged.shape[1]))]]
# Out:
#         Borough  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 23   North York               4                  Park     Convenience Store
# 25   North York               4     Food & Drink Shop                  Park
# 40    East York               4                  Park     Convenience Store
# 74         York               4                  Park         Women's Store
# 98         York               4                  Park         Women's Store
# 100   Etobicoke               4                  Park           Pizza Place
#
#           3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 23                Women's Store             Drugstore                 Diner
# 25   Construction & Landscaping   Dumpling Restaurant        Discount Store
# 40                Women's Store             Drugstore                 Diner
# 74                         Pool            Donut Shop    Dim Sum Restaurant
# ...
